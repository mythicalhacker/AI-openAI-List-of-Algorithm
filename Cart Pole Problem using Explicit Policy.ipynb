# %%
import gym
from gym import wrappers
import numpy as np
import matplotlib.pyplot as plt

# %%
def explicitPolicy(state):
    act=0
    if state<0:
        return act
    else:
        return 1
env = gym.make('CartPole-v0')

# %%
rewards=list()
for i in range(1000):
    obs=env.reset()
    reward=0    
    finished=False
    while not finished:      
        act=explicitPolicy(obs[2])            
        obs_,r,finished,info=env.step(act)
        reward+=r
        ob=obs_
    rewards.append(reward)
plt.plot(rewards)
plt.show()
